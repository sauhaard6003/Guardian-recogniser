# %%
import matplotlib.pyplot as plt
import cv2 as cv
import os
import numpy as np
from deepface import DeepFace

# %%
x1 = np.random.random_integers(1,8,(64,64,3))

# %%
img1 = cv.imread("KinFaceW-II\\images\\father-dau\\fd_250_1.jpg")
img2 = cv.imread("KinFaceW-II\\images\\mother-dau\\md_250_1.jpg")

# %%
#img2 = img1+x1

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
cv.imwrite("image.jpg",img2)
# Out:
# True

# %%
result = DeepFace.verify(img1_path = "KinFaceW-II\\images\\father-dau\\fd_250_1.jpg", img2_path = "KinFaceW-II\\images\\mother-dau\\md_250_1.jpg",enforce_detection=False)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
result
# Out:
# {'verified': False,
#  'distance': 0.5102174060588047,
#  'threshold': 0.4,
#  'model': 'VGG-Face',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine'}
